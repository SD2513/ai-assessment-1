# %% [markdown]
# <a href="https://colab.research.google.com/github/SD2513/ai-assessment-1/blob/main/2407091_ShlokDhital.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 3.1 Problem - 1:
# Data exploration and understanding

import pandas as pd

# Read dataset, show first 10 columns
whr = pd.read_csv('WHR-2024-5CS037.csv')
whr.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 3                    0.724                         0.838       0.221
# 4                    0.740                         0.641       0.153
# 5                    0.706                         0.725       0.247
# 6                    0.704                         0.835       0.224
# 7                    0.708                         0.801       0.146
# 8                    0.747                         0.759       0.173
# 9                    0.692                         0.756       0.225
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050
# 3                      0.524                1.658
# 4                      0.193                2.298
# 5                      0.372                1.906
# 6                      0.484                1.586
# 7                      0.432                1.540
# 8                      0.498                1.488
# 9                      0.323                1.745

# %%
# Print number of rows, colums and datatypes
print("Number of columns:", whr.columns.size)
print("Number of rows:", whr.index.size)
print("Data types: ")
whr.dtypes
# Out:
# Number of columns: 9
# Number of rows: 143
# Data types:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %%
# Basic Statistics

whr["score"].describe()
# Out:
# count    143.000000
# mean       5.527580
# std        1.170717
# min        1.721000
# 25%        4.726000
# 50%        5.785000
# 75%        6.416000
# max        7.741000
# Name: score, dtype: float64

# %%
# Find country with highest score

whr.loc[whr["score"]== whr["score"].max(),['Country name', 'score']]
# Out:
#   Country name  score
# 0      Finland  7.741

# %%
# Find country with lowest score

whr.loc[whr["score"]== whr["score"].min(),['Country name', 'score']]
# Out:
#     Country name  score
# 142  Afghanistan  1.721

# %%
# Find number of missing values in each column of dataset

whr.isnull().sum()
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %%
# Filter countries with scores greater than 7.5

highest_scores = whr.loc[whr["score"]>7.5]

# %%
# Sort dataset by GDP per Capita (Descending)

highest_score_srt_gdp = highest_scores.sort_values(by='Log GDP per capita', ascending=False)
highest_score_srt_gdp.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %%
# Add Happiness Category column

# Define categorize_happiness function
def categorize_happiness(score):
  if score < 4: return "Low"
  if score <= 6: return "Medium"
  return "High"

whr["Happiness_Category"] = whr["score"].apply(categorize_happiness)
# Show a sample to check if categorize working properly
whr.sample(n=10)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 13       Austria  6.905               1.885           1.336
# 35         Spain  6.421               1.766           1.471
# 38        Panama  6.358               1.702           1.392
# 63        Greece  5.934               1.684           1.276
# 25       Uruguay  6.611               1.596           1.431
# 14        Canada  6.900               1.840           1.459
# 17       Czechia  6.822               1.783           1.511
# 137     Zimbabwe  3.341               0.748           0.850
# 59         China  5.973               1.497           1.239
# 78     Venezuela  5.607               0.000           1.321
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 13                     0.696                         0.703       0.214
# 35                     0.729                         0.619       0.119
# 38                     0.633                         0.720       0.063
# 63                     0.696                         0.337       0.018
# 25                     0.592                         0.775       0.106
# 14                     0.701                         0.730       0.230
# 17                     0.638                         0.787       0.177
# 137                    0.232                         0.487       0.096
# 59                     0.629                         0.704       0.132
# 78                     0.491                         0.518       0.192
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category
# 13                       0.305                1.766               High
# 35                       0.177                1.540               High
# 38                       0.043                1.806               High
# 63                       0.093                1.830             Medium
# 25                       0.220                1.891               High
# 14                       0.368                1.572               High
# 17                       0.068                1.858               High
# 137                      0.131                0.797                Low
# 59                       0.164                1.608             Medium
# 78                       0.086                2.998             Medium

# %%
# 3.1 Problem - 1:
# Data Visualizations

import matplotlib.pyplot as plt

# Bar plot: Top 10 countries with highest scores
# Extract top 10 countries and plot into bar chart
top_10 = whr[['Country name', 'score']].sort_values(by='score', ascending=False).head(10)
top_10.plot(kind='bar', x='Country name', y='score', legend=None)
# Enter chart title and axis labels
plt.title('Top 10 Happiest Countries by Happiness Score')
plt.xlabel('Country')
plt.ylabel('Score')
# Y axis from lowest - 0.2 to highest + 0.2 so that difference in scores is seen
plt.ylim(bottom=top_10['score'].min()-0.2, top=top_10['score'].max()+0.2)
plt.show()

# %%
# Line plot: top 10 unhappiest countries by score

# Extract 10 unhappiest countries
bottom_10 = whr[['Country name', 'score']].sort_values(by='score').head(10)
bottom_10.plot(kind='line', x='Country name', y='score', marker='o', legend=None)
# Enter chart title and axis labels
plt.title('Top 10 Unhappiest Countries by Happiness Score')
plt.xlabel('Country')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')
